# %% [markdown]
# # NAME: CHARULIKA SHARMA

# %% [markdown]
# # The Sparks Foundation #GRIPFEB21  TASK:3

# %% [markdown]
# # Task: Exploratory Data Analysis - Retail (Level - Beginner)

# %% [markdown]
# Work:
# (i) As a business manager, try to find out the weak areas where you can work to make more profit.
# (ii) What all business problems you can derive by exploring the data?

# %% [markdown]
# # Importing the Libraries

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %% [markdown]
# These are the specific libraries, that i will need in future process.

# %% [markdown]
# # Importation of the Data

# %%
retaildata=pd.read_csv("SampleSuperstore.csv")

# %% [markdown]
# This is the command, to import the data

# %%
retaildata
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %% [markdown]
# This is our data, and as written below the data set, there are 994 rows and 13 columns.

# %% [markdown]
# # Data Analysis

# %%
retaildata.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %% [markdown]
# As our Data is Quite long, we are breaking it into top 5 elements of our data by the HEAD command.

# %%
retaildata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %% [markdown]
# The INFO command is used to find the summary of the data set.

# %%
retaildata.shape
# Out:
# (9994, 13)

# %%
retaildata.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %% [markdown]
# As we know that Quantity and Discount can never be negative. hence, it is necessary to check for the type of data so that it can be removed.

# %%
retaildata.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# The DESCRIBE command is used to find the statistical summary of our dataset.

# %%
retaildata.isnull()
# Out:
#       Ship Mode  Segment  Country   City  State  Postal Code  Region  \
# 0         False    False    False  False  False        False   False
# 1         False    False    False  False  False        False   False
# 2         False    False    False  False  False        False   False
# 3         False    False    False  False  False        False   False
# 4         False    False    False  False  False        False   False
# ...         ...      ...      ...    ...    ...          ...     ...
# 9989      False    False    False  False  False        False   False
# 9990      False    False    False  False  False        False   False
# 9991      False    False    False  False  False        False   False
# 9992      False    False    False  False  False        False   False
# 9993      False    False    False  False  False        False   False
#
#       Category  Sub-Category  Sales  Quantity  Discount  Profit
# 0        False         False  False     False     False   False
# ...

# %% [markdown]
# The above command is used to find out if there are any null value present in our dataset. As the rsult comes out 0, it means there are no null values present.

# %%
retaildata.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# The above command is used to find out if there are any null value present in our dataset. As the rsult comes out 0, it means there are no null values present.

# %%
retaildata.duplicated().sum()
# Out:
# 17

# %% [markdown]
# The DUPLICATE command is used to find that is there any duplicate values present in our dataset.

# %%
retaildata.drop_duplicates()
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %% [markdown]
# As we can't work work with the duplicated values, hence itt is important to remove them. the DROP command is used to do the same. after performing the drop command the no of values in our data set has decresed. There are 9977 rows and 13 columns.

# %% [markdown]
# # Data Visualisation

# %%
sns.pairplot(retaildata)

# %% [markdown]
# The above graphs are the relation between different elements of our dataset.

# %%
sns.boxplot(x=retaildata['Profit'])
# Out:
# <AxesSubplot:xlabel='Profit'>

# %%
sns.boxplot(x=retaildata['Discount'])
# Out:
# <AxesSubplot:xlabel='Discount'>

# %%
sns.boxplot(x=retaildata['Quantity'])
# Out:
# <AxesSubplot:xlabel='Quantity'>

# %% [markdown]
# The data is clean and ready for anlysis.

# %% [markdown]
# # Diving deep into the Data analysis part

# %%
Q1=retaildata.quantile(0.25)

# %%
Q3=retaildata.quantile(0.25)

# %%
IQR=Q3-Q1

# %%
print(IQR)
# Out:
# Postal Code    0.0
# Sales          0.0
# Quantity       0.0
# Discount       0.0
# Profit         0.0
# Name: 0.25, dtype: float64

# %%
retaildata.max()
# Out:
# Ship Mode       Standard Class
# Segment            Home Office
# Country          United States
# City                      Yuma
# State                  Wyoming
# Postal Code              99301
# Region                    West
# Category            Technology
# Sub-Category            Tables
# Sales                  22638.5
# Quantity                    14
# Discount                   0.8
# Profit                 8399.98
# dtype: object

# %%
retaildata.min()
# Out:
# Ship Mode         First Class
# Segment              Consumer
# Country         United States
# City                 Aberdeen
# State                 Alabama
# Postal Code              1040
# Region                Central
# Category            Furniture
# Sub-Category      Accessories
# Sales                   0.444
# Quantity                    1
# Discount                    0
# Profit               -6599.98
# dtype: object

# %%
c_1=retaildata["Sales"]

# %%
c_2=retaildata["Profit"]

# %%
correlation=c_1.corr(c_2)

# %%
print(correlation)
# Out:
# 0.4790643497377058

# %%
c_1=retaildata["Discount"]

# %%
c_2=retaildata["Profit"]

# %%
correlation=c_2.corr(c_1)

# %%
print(correlation)
# Out:
# -0.21948745637176809

# %%
c_1=retaildata["Sales"]

# %%
c_2=retaildata["Sales"]

# %%
correlation=c_1.corr(c_2)

# %%
print(correlation)
# Out:
# 0.9999999999999998

# %%
f,ax=plt.subplots(figsize=(11,11))
sns.heatmap(retaildata.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# The above digrams show the correlation between different elements of the data set.

# %%
plt.figure(figsize=(6,6))
plt.pie(retaildata['Category'].value_counts(),labels=retaildata['Category'].value_counts().index,autopct='%1.1f%%')
plt.show()

# %% [markdown]
# From the above data we can conclude that, Office supplies is the most popular category overall with the 60.3% observations. Technology and furniture are quite similar, with 18.5% and 21.2% respectively.

# %%
retaildata['State'].value_counts()
# Out:
# California              2001
# New York                1128
# Texas                    985
# Pennsylvania             587
# Washington               506
# Illinois                 492
# Ohio                     469
# Florida                  383
# Michigan                 255
# North Carolina           249
# Virginia                 224
# Arizona                  224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   124
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Oklahoma                  66
# Missouri                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Mississippi               53
# Utah                      53
# ...

# %% [markdown]
# California is the favourite of all as it has 2001 rows, which meand that there could be high business from this state. and we can understant the othere sata repesentation in the same way

# %%
retaildata['Profit'].describe()
# Out:
# count    9994.000000
# mean       28.656896
# std       234.260108
# min     -6599.978000
# 25%         1.728750
# 50%         8.666500
# 75%        29.364000
# max      8399.976000
# Name: Profit, dtype: float64

# %% [markdown]
# # Checking Quantity Data

# %%
plt.hist(retaildata['Quantity'],bins=9)
plt.show()

# %% [markdown]
# As from the figure we can say that people are more willing to buy 2 quantities of the good rather then 4,5,6...

# %%
plt.hist(retaildata['Discount'],bins=9)
plt.show()

# %%
plt.figure(figsize=(20,20))
retaildata['State'].value_counts().plot(kind='bar',title=('State'))
# Out:
# <AxesSubplot:title={'center':'State'}>

# %%
fig,ax=plt.subplots(1,1,figsize=(12,7))
sns.countplot(retaildata['Quantity'],hue=retaildata['Region'])
plt.show()
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Thank You
